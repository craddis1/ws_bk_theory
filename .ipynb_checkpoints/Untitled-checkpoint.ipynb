# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
for i in range(8):
    f = np.arange(10)
    plt.plot(i*f)

# %%
plt.style.use('tableau-colorblind10')
plt.figure(figsize=(12,6))
for i in range(8):
    f = np.arange(10)
    plt.plot(i*f)
