# %%
import json
from sympy.parsing.mathematica import mathematica  
with open('cov/cov11.json') as f:
    data = json.load(f)
tmpexp = str(mathematica(data)).replace('I*','1j*').replace('-I*','-1j*').replace('sqrt(','np.sqrt(').replace('pi','np.pi')
print(tmpexp)
# Out:
# 3*D1*f*(Pk2*(D1*Pk1*nbar*(D1*Pk3*nbar*(21*b1**2*k2**2 + 21*b1**2*k3**2 + 3*b1*f*k1**2 + 21*b1*f*k2**2 + 3*b1*f*k3**2 + f**2*k1**2 + 2*f**2*k2**2*cos(2*theta) + 4*f**2*k2**2 + 6*f*k1*k2*(3*b1 + f)*cos(theta)) + k3**2*(21*b1 + 3*f)) + 3*D1*Pk3*nbar*(7*b1*(k2**2 + k3**2) + 6*f*k1*k2*cos(theta) + f*(k1**2 + 6*k2**2)) + 21*k3**2) + 3*Pk3*k2**2*(D1*Pk1*nbar*(7*b1 + f) + 7))*sin(theta)**2/(35*Nt*k3**2*nbar**2)

# %%
with open("tmp.txt", "w") as file:
    file.write(str(tmpexp))
